# %% [markdown]
# <a href="https://colab.research.google.com/github/pydeoxy/llm_apps/blob/main/nllb_200_1_3b_translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
import torch

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
translator = pipeline(task="translation",
                      model="facebook/nllb-200-1.3B",
                      torch_dtype=torch.bfloat16)
# Out:
# config.json:   0%|          | 0.00/808 [00:00<?, ?B/s]
# c:\Users\yan.peng\.env\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\yan.peng\.cache\huggingface\hub\models--facebook--nllb-200-1.3B. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/5.48G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]

# %%
text = """Pekka Einari Salminen on suomalainen, professorin arvonimen saanut arkkitehti.
            Hän suoritti ensin insinöörin tutkinnon arkkitehtuurin opintosuunnalla Tampereen teknillisessä opistossa,
            ja jatkoi sitten opintojaan Teknillisessä korkeakoulussa, josta valmistui arkkitehdiksi vuonna 1966."""

# %%
text_translated = translator(text,
                             src_lang="fin_Latn",
                             tgt_lang="eng_Latn")

# %%
text_translated
# Out:
# [{'translation_text': 'Pekka Einari Salminen is a Finnish architect, who was awarded the title of professor. He first completed his engineering degree in architecture at the Tampere University of Technology, and then continued his studies at the Technical University, graduating as an architect in 1966.'}]
